# %%
import duckdb
import pandas as pd
from nyc_taxi.config.settings import DATABASE_PATH

# Connect to a file-based database (or ':memory:' for temporary)
con = duckdb.connect(DATABASE_PATH)

# Execute query and convert to pandas
yellow = con.sql("SELECT * FROM raw_taxi.yellow_taxi").df()

yellow.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2025-01-01 00:18:38   2025-01-01 00:26:59                1
# 1         1  2025-01-01 00:32:40   2025-01-01 00:35:13                1
# 2         1  2025-01-01 00:44:04   2025-01-01 00:46:01                1
# 3         2  2025-01-01 00:14:27   2025-01-01 00:20:01                3
# 4         2  2025-01-01 00:21:34   2025-01-01 00:25:06                3
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.60           1                  N           229           237
# 1           0.50           1                  N           236           237
# 2           0.60           1                  N           141           141
# 3           0.52           1                  N           244           244
# 4           0.66           1                  N           244           116
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
yellow.shape
# Out:
# (15168579, 20)

# %%
green = con.sql("SELECT * FROM raw_taxi.green_taxi").df()
# Out:
# ---------------------------------------------------------------------------
# CatalogException                          Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 green = con.sql("SELECT * FROM raw_taxi.green_taxi").df()
#
# CatalogException: Catalog Error: Table with name green_taxi does not exist!
# Did you mean "yellow_taxi"?

# %%
green.shape
# Out:
# (1463, 19)

# %%
green.head()
# Out:
#   vendorid     lpep_pickup_datetime    lpep_dropoff_datetime  \
# 0        2  2023-01-01T00:01:31.000  2023-01-01T00:16:02.000
# 1        2  2023-01-01T00:04:25.000  2023-01-01T00:17:50.000
# 2        2  2023-01-01T00:06:48.000  2023-01-01T01:08:47.000
# 3        2  2023-01-01T00:08:05.000  2023-01-01T00:13:26.000
# 4        2  2023-01-01T00:08:43.000  2023-01-01T00:17:08.000
#
#   store_and_fwd_flag ratecodeid pulocationid dolocationid passenger_count  \
# 0                  N        1.0          166          244             1.0
# 1                  N        1.0          255          146             1.0
# 2                  N        1.0          129          226             2.0
# 3                  N        1.0           41           75             6.0
# 4                  N        1.0           75          140             1.0
#
#   trip_distance fare_amount extra mta_tax tip_amount tolls_amount  \
# 0          2.48        16.3   1.0     0.5       3.76          0.0
# ...

# %%
green.tail()
# Out:
#      vendorid     lpep_pickup_datetime    lpep_dropoff_datetime  \
# 1458        2  2023-01-01T23:44:20.000  2023-01-02T00:20:24.000
# 1459        2  2023-01-01T23:47:07.000  2023-01-01T23:57:07.000
# 1460        2  2023-01-01T23:53:24.000  2023-01-02T00:05:41.000
# 1461        2  2023-01-01T23:53:37.000  2023-01-02T00:21:56.000
# 1462        2  2023-01-01T23:55:51.000  2023-01-02T00:03:41.000
#
#      store_and_fwd_flag ratecodeid pulocationid dolocationid passenger_count  \
# 1458                  N        1.0          255           50             3.0
# 1459                  N        5.0          260          260             0.0
# 1460                  N        1.0           17           80             5.0
# 1461                  N        1.0          223           50             1.0
# 1462                  N        1.0           74           75             1.0
#
#      trip_distance fare_amount extra mta_tax tip_amount tolls_amount  \
# ...

# %%
import pyarrow
print(pyarrow.__version__)
# Out:
# 23.0.1

# %%
import duckdb
print(duckdb.__version__)
# Out:
# 1.5.1
